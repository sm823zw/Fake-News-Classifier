# %%
import pickle
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def convert_data(data):
    sentence = data[0]
    corpus = [' '.join(item) for item in sentence]
    label = data[1]
    empty_idx = []
    for i in range(len(corpus)):
        if corpus[i] == '':
            empty_idx.append(i)
    empty_idx.sort(reverse=True)
    for i in empty_idx:
        del corpus[i]
        del sentence[i]
        del label[i]
    label = np.array(label)
    data_convert = [sentence, label]
    return data_convert, corpus
    
def glove_dict():
    embedding_dict = {}

    # Open the GloVe embedding file
    glove_dir = 'Embedding/glove.6B.100d.txt'
    file = open(glove_dir, encoding="utf8")

    for line in file:
        # Spilt the word and its embedding vector
        line_list = line.split(' ')
        word = line_list[0]
        embeddings = np.asarray(line_list[1:], dtype='float32')

        # Store the word and its embedding vector in a dictionary
        embedding_dict[word] = embeddings

    file.close()

    # Store the dictionary as a pickle file to reduce thw overhead of loading
    with open(f'Embedding/glove_dict_6b_100d.pickle', "wb") as file:
        pickle.dump(embedding_dict, file)

    return embedding_dict

def embedding_matrix(corpus, VOCAB_SIZE):
    # Try to load GloVe embedding dictionary if it exists. If not, create one
    try:
        with open(f'Embedding/glove_dict_6b_100d.pickle', "rb") as file:
            glove_embedding = pickle.load(file)
    except:
        glove_embedding = glove_dict()

    # Initialize and fit Keras tokenizer to convert words to integers
    tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=VOCAB_SIZE)
    tokenizer.fit_on_texts(corpus)

    # Save the tokenizer as a pickle file so that the same tokenizer (word-integer)
    # mapping can be used during testing time
    with open('Tokenizer/tokenizer.pickle', "wb") as file:
        pickle.dump(tokenizer, file)

    # Get an word-integer dictionary and use that to create an weight matrix
    # i-th column of weight matrix will have the vector of word with integer value i in dictionary
    word_index = tokenizer.word_index
    embed_matrix = np.zeros((len(word_index) + 1, 100))

    for word, ind in word_index.items():
        # Get the embedding vector from GloVe dictionary, if available
        # Words not in the Glove would have the embedding matrix vector as random values uniformly generated between -0.05 and 0.05
        embedding_vector = glove_embedding.get(word)

        if embedding_vector is not None:
            embed_matrix[ind] = embedding_vector
        else:
            embed_matrix[ind] = np.array([np.random.uniform(-0.05, 0.05) for _ in range(100)])

    return embed_matrix, tokenizer

# %%
with open('title_data.pickle', "rb") as file:
        data = pickle.load(file)

# %%
sen = data[0]
lab = data[1]

# %%
train_data = [sen[0:17000], lab[0:17000]]
test_data = [sen[17000:], lab[17000:]]

# %%
MAX_SEQ_LEN = 30
VOCAB_SIZE = 20000

# %%
train_data, corpus = convert_data(train_data)
embed_matrix, tokenizer = embedding_matrix(corpus, VOCAB_SIZE)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
train_data = process(train_data)

# %%
embed_matrix.shape
# Out:
# (13779, 100)

# %%
lam = tf.keras.regularizers.L2(l2=0.05)
embedding = tf.keras.layers.Embedding(input_dim=embed_matrix.shape[0], output_dim=100, weights=[embed_matrix], input_length=MAX_SEQ_LEN, trainable=False)
translation = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(100, activation='relu', kernel_regularizer=lam))
lstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(100, kernel_regularizer=lam))

# %%
input_layer = tf.keras.layers.Input(shape=(MAX_SEQ_LEN,), dtype='int32')
embed_layer = embedding(input_layer)
translate_layer = translation(embed_layer)
lstm_layer = lstm(translate_layer)
dense_layer = tf.keras.layers.Dense(100, activation='relu', kernel_regularizer=lam)(lstm_layer)
dropout_layer = tf.keras.layers.Dropout(0.2)(dense_layer)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(dropout_layer)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 30, 100)           1377900
# _________________________________________________________________
# time_distributed (TimeDistri (None, 30, 100)           10100
# _________________________________________________________________
# bidirectional (Bidirectional (None, 200)               160800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 1,569,001
# Trainable params: 191,101
# Non-trainable params: 1,377,900
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=6, verbose=1, factor=0.5, min_lr=0.00001)

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)

_, tmpfn = tempfile.mkstemp()
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)

callbacks = [model_checkpoint, learning_rate_reduction]

# %%
X_train = train_data[0]
y_train = train_data[1]

# %%
history = model.fit(x=X_train, y=y_train, epochs=100, batch_size=128, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/150
# 119/119 [==============================] - 9s 31ms/step - loss: 3.6619 - accuracy: 0.7535 - val_loss: 0.7479 - val_accuracy: 0.8974
# Epoch 2/150
# 119/119 [==============================] - 2s 18ms/step - loss: 0.6299 - accuracy: 0.9051 - val_loss: 0.5147 - val_accuracy: 0.8962
# Epoch 3/150
# 119/119 [==============================] - 2s 17ms/step - loss: 0.4908 - accuracy: 0.9096 - val_loss: 0.4570 - val_accuracy: 0.8938
# Epoch 4/150
# 119/119 [==============================] - 2s 17ms/step - loss: 0.4360 - accuracy: 0.9079 - val_loss: 0.3934 - val_accuracy: 0.8956
# Epoch 5/150
# 119/119 [==============================] - 2s 17ms/step - loss: 0.3759 - accuracy: 0.9079 - val_loss: 0.3573 - val_accuracy: 0.8885
# Epoch 6/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.4708 - accuracy: 0.8540 - val_loss: 0.4554 - val_accuracy: 0.8980
# Epoch 7/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.4256 - accuracy: 0.9062 - val_loss: 0.3877 - val_accuracy: 0.8986
# Epoch 8/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3582 - accuracy: 0.9144 - val_loss: 0.3448 - val_accuracy: 0.9069
# Epoch 9/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3217 - accuracy: 0.9180 - val_loss: 0.3190 - val_accuracy: 0.9081
# Epoch 10/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2995 - accuracy: 0.9270 - val_loss: 0.3117 - val_accuracy: 0.9146
# Epoch 11/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2891 - accuracy: 0.9260 - val_loss: 0.2932 - val_accuracy: 0.9152
# Epoch 12/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2815 - accuracy: 0.9246 - val_loss: 0.2944 - val_accuracy: 0.9187
# Epoch 13/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.2718 - accuracy: 0.9273 - val_loss: 0.2654 - val_accuracy: 0.9306
# Epoch 14/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2609 - accuracy: 0.9300 - val_loss: 0.2795 - val_accuracy: 0.9181
# Epoch 15/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2580 - accuracy: 0.9301 - val_loss: 0.2656 - val_accuracy: 0.9176
# Epoch 16/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2455 - accuracy: 0.9339 - val_loss: 0.2707 - val_accuracy: 0.9170
# Epoch 17/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2383 - accuracy: 0.9360 - val_loss: 0.2760 - val_accuracy: 0.9211
# Epoch 18/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2378 - accuracy: 0.9365 - val_loss: 0.2542 - val_accuracy: 0.9199
# Epoch 19/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2325 - accuracy: 0.9354 - val_loss: 0.2721 - val_accuracy: 0.9181
# Epoch 20/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.2212 - accuracy: 0.9389 - val_loss: 0.2486 - val_accuracy: 0.9247
# Epoch 21/150
# 119/119 [==============================] - 2s 17ms/step - loss: 0.2176 - accuracy: 0.9422 - val_loss: 0.2428 - val_accuracy: 0.9247
# Epoch 22/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.2097 - accuracy: 0.9441 - val_loss: 0.2405 - val_accuracy: 0.9282
# Epoch 23/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2173 - accuracy: 0.9418 - val_loss: 0.2371 - val_accuracy: 0.9306
# Epoch 24/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.2077 - accuracy: 0.9447 - val_loss: 0.2895 - val_accuracy: 0.9152
# Epoch 25/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2113 - accuracy: 0.9444 - val_loss: 0.2521 - val_accuracy: 0.9253
# Epoch 26/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1984 - accuracy: 0.9491 - val_loss: 0.2417 - val_accuracy: 0.9282
# Epoch 27/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1942 - accuracy: 0.9501 - val_loss: 0.2431 - val_accuracy: 0.9276
# Epoch 28/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1974 - accuracy: 0.9507 - val_loss: 0.2489 - val_accuracy: 0.9253
# Epoch 29/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1877 - accuracy: 0.9534 - val_loss: 0.2657 - val_accuracy: 0.9199
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1822 - accuracy: 0.9548 - val_loss: 0.2507 - val_accuracy: 0.9324
# Epoch 31/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1653 - accuracy: 0.9618 - val_loss: 0.2410 - val_accuracy: 0.9235
# Epoch 32/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1640 - accuracy: 0.9634 - val_loss: 0.2411 - val_accuracy: 0.9312
# Epoch 33/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1669 - accuracy: 0.9612 - val_loss: 0.2411 - val_accuracy: 0.9306
# Epoch 34/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1628 - accuracy: 0.9640 - val_loss: 0.2430 - val_accuracy: 0.9312
# Epoch 35/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1655 - accuracy: 0.9624 - val_loss: 0.2494 - val_accuracy: 0.9253
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 36/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1499 - accuracy: 0.9695 - val_loss: 0.2659 - val_accuracy: 0.9342
# Epoch 37/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1475 - accuracy: 0.9705 - val_loss: 0.2736 - val_accuracy: 0.9270
# Epoch 38/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1454 - accuracy: 0.9729 - val_loss: 0.2753 - val_accuracy: 0.9294
# Epoch 39/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1375 - accuracy: 0.9752 - val_loss: 0.2669 - val_accuracy: 0.9259
# Epoch 40/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1377 - accuracy: 0.9748 - val_loss: 0.2627 - val_accuracy: 0.9276
# Epoch 41/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1342 - accuracy: 0.9772 - val_loss: 0.2719 - val_accuracy: 0.9282
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 42/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1272 - accuracy: 0.9805 - val_loss: 0.2826 - val_accuracy: 0.9235
# Epoch 43/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1263 - accuracy: 0.9812 - val_loss: 0.2837 - val_accuracy: 0.9229
# Epoch 44/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1253 - accuracy: 0.9812 - val_loss: 0.2838 - val_accuracy: 0.9247
# Epoch 45/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1237 - accuracy: 0.9827 - val_loss: 0.2953 - val_accuracy: 0.9241
# Epoch 46/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1197 - accuracy: 0.9826 - val_loss: 0.2948 - val_accuracy: 0.9199
# Epoch 47/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1227 - accuracy: 0.9819 - val_loss: 0.2915 - val_accuracy: 0.9235
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 48/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1119 - accuracy: 0.9869 - val_loss: 0.2970 - val_accuracy: 0.9217
# Epoch 49/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1122 - accuracy: 0.9863 - val_loss: 0.3104 - val_accuracy: 0.9223
# Epoch 50/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1158 - accuracy: 0.9848 - val_loss: 0.3024 - val_accuracy: 0.9217
# Epoch 51/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1122 - accuracy: 0.9870 - val_loss: 0.3100 - val_accuracy: 0.9205
# Epoch 52/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1090 - accuracy: 0.9887 - val_loss: 0.3102 - val_accuracy: 0.9211
# Epoch 53/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1047 - accuracy: 0.9899 - val_loss: 0.3127 - val_accuracy: 0.9211
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 54/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1104 - accuracy: 0.9882 - val_loss: 0.3121 - val_accuracy: 0.9199
# Epoch 55/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1081 - accuracy: 0.9891 - val_loss: 0.3129 - val_accuracy: 0.9223
# Epoch 56/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1023 - accuracy: 0.9898 - val_loss: 0.3152 - val_accuracy: 0.9223
# Epoch 57/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1076 - accuracy: 0.9889 - val_loss: 0.3175 - val_accuracy: 0.9205
# Epoch 58/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.1050 - accuracy: 0.9900 - val_loss: 0.3189 - val_accuracy: 0.9229
# Epoch 59/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.1039 - accuracy: 0.9910 - val_loss: 0.3220 - val_accuracy: 0.9211
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 60/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1040 - accuracy: 0.9920 - val_loss: 0.3221 - val_accuracy: 0.9235
# Epoch 61/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0989 - accuracy: 0.9921 - val_loss: 0.3223 - val_accuracy: 0.9211
# Epoch 62/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1017 - accuracy: 0.9919 - val_loss: 0.3242 - val_accuracy: 0.9199
# Epoch 63/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1086 - accuracy: 0.9904 - val_loss: 0.3248 - val_accuracy: 0.9176
# Epoch 64/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1048 - accuracy: 0.9895 - val_loss: 0.3253 - val_accuracy: 0.9223
# Epoch 65/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1001 - accuracy: 0.9918 - val_loss: 0.3275 - val_accuracy: 0.9170
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 66/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1042 - accuracy: 0.9917 - val_loss: 0.3268 - val_accuracy: 0.9235
# Epoch 67/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1002 - accuracy: 0.9929 - val_loss: 0.3275 - val_accuracy: 0.9223
# Epoch 68/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1028 - accuracy: 0.9913 - val_loss: 0.3287 - val_accuracy: 0.9193
# Epoch 69/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0988 - accuracy: 0.9929 - val_loss: 0.3296 - val_accuracy: 0.9235
# Epoch 70/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1005 - accuracy: 0.9924 - val_loss: 0.3301 - val_accuracy: 0.9235
# Epoch 71/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1021 - accuracy: 0.9913 - val_loss: 0.3304 - val_accuracy: 0.9170
# Epoch 72/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0996 - accuracy: 0.9928 - val_loss: 0.3306 - val_accuracy: 0.9235
# Epoch 73/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.1030 - accuracy: 0.9920 - val_loss: 0.3317 - val_accuracy: 0.9152
# Epoch 74/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1014 - accuracy: 0.9924 - val_loss: 0.3315 - val_accuracy: 0.9193
# Epoch 75/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1002 - accuracy: 0.9917 - val_loss: 0.3324 - val_accuracy: 0.9193
# Epoch 76/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0974 - accuracy: 0.9934 - val_loss: 0.3333 - val_accuracy: 0.9229
# Epoch 77/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0976 - accuracy: 0.9914 - val_loss: 0.3334 - val_accuracy: 0.9187
# Epoch 78/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0990 - accuracy: 0.9921 - val_loss: 0.3352 - val_accuracy: 0.9164
# Epoch 79/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1000 - accuracy: 0.9921 - val_loss: 0.3352 - val_accuracy: 0.9223
# Epoch 80/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0979 - accuracy: 0.9936 - val_loss: 0.3350 - val_accuracy: 0.9199
# Epoch 81/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1026 - accuracy: 0.9908 - val_loss: 0.3348 - val_accuracy: 0.9205
# Epoch 82/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0975 - accuracy: 0.9929 - val_loss: 0.3352 - val_accuracy: 0.9205
# Epoch 83/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.1009 - accuracy: 0.9917 - val_loss: 0.3360 - val_accuracy: 0.9170
# Epoch 84/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1019 - accuracy: 0.9913 - val_loss: 0.3357 - val_accuracy: 0.9205
# Epoch 85/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0975 - accuracy: 0.9922 - val_loss: 0.3370 - val_accuracy: 0.9211
# Epoch 86/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0961 - accuracy: 0.9938 - val_loss: 0.3381 - val_accuracy: 0.9199
# Epoch 87/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1000 - accuracy: 0.9921 - val_loss: 0.3385 - val_accuracy: 0.9158
# Epoch 88/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0983 - accuracy: 0.9926 - val_loss: 0.3389 - val_accuracy: 0.9187
# Epoch 89/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0975 - accuracy: 0.9917 - val_loss: 0.3398 - val_accuracy: 0.9176
# Epoch 90/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0946 - accuracy: 0.9934 - val_loss: 0.3387 - val_accuracy: 0.9199
# Epoch 91/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.0964 - accuracy: 0.9934 - val_loss: 0.3394 - val_accuracy: 0.9158
# Epoch 92/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.0955 - accuracy: 0.9942 - val_loss: 0.3392 - val_accuracy: 0.9164
# Epoch 93/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0998 - accuracy: 0.9918 - val_loss: 0.3407 - val_accuracy: 0.9205
# Epoch 94/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0985 - accuracy: 0.9927 - val_loss: 0.3408 - val_accuracy: 0.9211
# Epoch 95/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0967 - accuracy: 0.9931 - val_loss: 0.3413 - val_accuracy: 0.9176
# Epoch 96/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0946 - accuracy: 0.9939 - val_loss: 0.3408 - val_accuracy: 0.9181
# Epoch 97/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.1012 - accuracy: 0.9920 - val_loss: 0.3410 - val_accuracy: 0.9176
# Epoch 98/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0942 - accuracy: 0.9937 - val_loss: 0.3420 - val_accuracy: 0.9181
# Epoch 99/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0953 - accuracy: 0.9927 - val_loss: 0.3422 - val_accuracy: 0.9158
# Epoch 100/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0983 - accuracy: 0.9933 - val_loss: 0.3424 - val_accuracy: 0.9176
# Epoch 101/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0931 - accuracy: 0.9946 - val_loss: 0.3434 - val_accuracy: 0.9205
# Epoch 102/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0965 - accuracy: 0.9936 - val_loss: 0.3431 - val_accuracy: 0.9152
# Epoch 103/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0931 - accuracy: 0.9940 - val_loss: 0.3425 - val_accuracy: 0.9199
# Epoch 104/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0977 - accuracy: 0.9932 - val_loss: 0.3446 - val_accuracy: 0.9205
# Epoch 105/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0957 - accuracy: 0.9938 - val_loss: 0.3451 - val_accuracy: 0.9140
# Epoch 106/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0983 - accuracy: 0.9917 - val_loss: 0.3438 - val_accuracy: 0.9164
# Epoch 107/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0950 - accuracy: 0.9936 - val_loss: 0.3446 - val_accuracy: 0.9152
# Epoch 108/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0989 - accuracy: 0.9919 - val_loss: 0.3444 - val_accuracy: 0.9181
# Epoch 109/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0980 - accuracy: 0.9929 - val_loss: 0.3444 - val_accuracy: 0.9158
# Epoch 110/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0946 - accuracy: 0.9933 - val_loss: 0.3447 - val_accuracy: 0.9146
# Epoch 111/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0987 - accuracy: 0.9926 - val_loss: 0.3457 - val_accuracy: 0.9152
# Epoch 112/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0945 - accuracy: 0.9942 - val_loss: 0.3465 - val_accuracy: 0.9152
# Epoch 113/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0952 - accuracy: 0.9940 - val_loss: 0.3475 - val_accuracy: 0.9176
# Epoch 114/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0980 - accuracy: 0.9929 - val_loss: 0.3478 - val_accuracy: 0.9152
# Epoch 115/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0949 - accuracy: 0.9939 - val_loss: 0.3496 - val_accuracy: 0.9140
# Epoch 116/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0936 - accuracy: 0.9938 - val_loss: 0.3493 - val_accuracy: 0.9181
# Epoch 117/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0981 - accuracy: 0.9938 - val_loss: 0.3484 - val_accuracy: 0.9152
# Epoch 118/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0911 - accuracy: 0.9952 - val_loss: 0.3482 - val_accuracy: 0.9158
# Epoch 119/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0946 - accuracy: 0.9936 - val_loss: 0.3479 - val_accuracy: 0.9152
# Epoch 120/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0931 - accuracy: 0.9940 - val_loss: 0.3498 - val_accuracy: 0.9146
# Epoch 121/150
# 119/119 [==============================] - 2s 17ms/step - loss: 0.0967 - accuracy: 0.9926 - val_loss: 0.3504 - val_accuracy: 0.9176
# Epoch 122/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.0968 - accuracy: 0.9930 - val_loss: 0.3498 - val_accuracy: 0.9158
# Epoch 123/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0950 - accuracy: 0.9935 - val_loss: 0.3513 - val_accuracy: 0.9181
# Epoch 124/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0977 - accuracy: 0.9932 - val_loss: 0.3508 - val_accuracy: 0.9158
# Epoch 125/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0940 - accuracy: 0.9934 - val_loss: 0.3514 - val_accuracy: 0.9158
# Epoch 126/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0958 - accuracy: 0.9936 - val_loss: 0.3516 - val_accuracy: 0.9176
# Epoch 127/150
# 119/119 [==============================] - 2s 16ms/step - loss: 0.0942 - accuracy: 0.9937 - val_loss: 0.3524 - val_accuracy: 0.9164
# Epoch 128/150
# 119/119 [==============================] - 2s 19ms/step - loss: 0.0932 - accuracy: 0.9938 - val_loss: 0.3510 - val_accuracy: 0.9152
# Epoch 129/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0949 - accuracy: 0.9932 - val_loss: 0.3518 - val_accuracy: 0.9164
# Epoch 130/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0910 - accuracy: 0.9946 - val_loss: 0.3530 - val_accuracy: 0.9187
# Epoch 131/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0917 - accuracy: 0.9942 - val_loss: 0.3542 - val_accuracy: 0.9146
# Epoch 132/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0926 - accuracy: 0.9946 - val_loss: 0.3543 - val_accuracy: 0.9176
# Epoch 133/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0949 - accuracy: 0.9930 - val_loss: 0.3544 - val_accuracy: 0.9140
# Epoch 134/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0927 - accuracy: 0.9935 - val_loss: 0.3534 - val_accuracy: 0.9158
# Epoch 135/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0939 - accuracy: 0.9933 - val_loss: 0.3534 - val_accuracy: 0.9134
# Epoch 136/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0908 - accuracy: 0.9949 - val_loss: 0.3544 - val_accuracy: 0.9164
# Epoch 137/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0925 - accuracy: 0.9943 - val_loss: 0.3558 - val_accuracy: 0.9187
# Epoch 138/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0916 - accuracy: 0.9943 - val_loss: 0.3556 - val_accuracy: 0.9164
# Epoch 139/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0890 - accuracy: 0.9952 - val_loss: 0.3562 - val_accuracy: 0.9146
# Epoch 140/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0904 - accuracy: 0.9941 - val_loss: 0.3576 - val_accuracy: 0.9146
# Epoch 141/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0899 - accuracy: 0.9941 - val_loss: 0.3574 - val_accuracy: 0.9152
# Epoch 142/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0904 - accuracy: 0.9940 - val_loss: 0.3569 - val_accuracy: 0.9170
# Epoch 143/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0953 - accuracy: 0.9932 - val_loss: 0.3586 - val_accuracy: 0.9146
# Epoch 144/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0928 - accuracy: 0.9941 - val_loss: 0.3578 - val_accuracy: 0.9152
# Epoch 145/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0894 - accuracy: 0.9952 - val_loss: 0.3573 - val_accuracy: 0.9164
# Epoch 146/150
# 119/119 [==============================] - 2s 15ms/step - loss: 0.0885 - accuracy: 0.9953 - val_loss: 0.3585 - val_accuracy: 0.9152
# Epoch 147/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0902 - accuracy: 0.9945 - val_loss: 0.3568 - val_accuracy: 0.9164
# Epoch 148/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0928 - accuracy: 0.9942 - val_loss: 0.3590 - val_accuracy: 0.9128
# Epoch 149/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0920 - accuracy: 0.9944 - val_loss: 0.3586 - val_accuracy: 0.9152
# Epoch 150/150
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0915 - accuracy: 0.9951 - val_loss: 0.3601 - val_accuracy: 0.9128

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
with open('Tokenizer/tokenizer.pickle', "rb") as file:
        tokenizer = pickle.load(file)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
test_data = process(test_data)

# %%
X_test = test_data[0]
y_test = np.array(test_data[1])

# %%
X_test.shape, y_test.shape
# Out:
# ((3242, 30), (3242,))

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}, Test Accuracy: {:.2f}%\n".format(loss, (accuracy*100)))
# Out:
# 102/102 [==============================] - 0s 4ms/step - loss: 0.3677 - accuracy: 0.9146
# Test Loss: 0.37, Test Accuracy: 91.46%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

# %%
plt.figure(figsize=(8, 6))
ticks = ['Reliable', 'Unreliable']
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g', xticklabels=ticks, yticklabels=ticks, annot_kws={"size":20})
plt.ylabel("True labels")
plt.xlabel("Predicted labels")
# Out:
# Text(0.5, 33.0, 'Predicted labels')

# %%
plt.figure(figsize=(8, 6))
report = classification_report(y_test, y_pred, output_dict=True, target_names=ticks)
sns.heatmap(pd.DataFrame(report).iloc[:-1, :2].T, annot=True, annot_kws={"size":20})
# Out:
# <AxesSubplot:>

# %%
tf.keras.models.save_model(model, 'title_model.h5')

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc
y_pred = model.predict(X_test)
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test, y_pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure()
lw = 2
plt.plot(fpr[1], tpr[1], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[1])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure()
lw = 2
plt.plot(fpr[0], tpr[0], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[0])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
