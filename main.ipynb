# %%
import pickle
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def convert_data(data):
    sentence = data[0]
    corpus = [' '.join(item) for item in sentence]
    label = data[1]
    empty_idx = []
    for i in range(len(corpus)):
        if corpus[i] == '':
            empty_idx.append(i)
    empty_idx.sort(reverse=True)
    for i in empty_idx:
        del corpus[i]
        del sentence[i]
        del label[i]
    label = np.array(label)
    data_convert = [sentence, label]
    return data_convert, corpus
    
def glove_dict():
    embedding_dict = {}

    # Open the GloVe embedding file
    glove_dir = 'Embedding/glove.6B.100d.txt'
    file = open(glove_dir, encoding="utf8")

    for line in file:
        # Spilt the word and its embedding vector
        line_list = line.split(' ')
        word = line_list[0]
        embeddings = np.asarray(line_list[1:], dtype='float32')

        # Store the word and its embedding vector in a dictionary
        embedding_dict[word] = embeddings

    file.close()

    # Store the dictionary as a pickle file to reduce thw overhead of loading
    with open(f'Embedding/glove_dict_6b_100d.pickle', "wb") as file:
        pickle.dump(embedding_dict, file)

    return embedding_dict

def embedding_matrix(corpus, VOCAB_SIZE):
    # Try to load GloVe embedding dictionary if it exists. If not, create one
    try:
        with open(f'Embedding/glove_dict_6b_100d.pickle', "rb") as file:
            glove_embedding = pickle.load(file)
    except:
        glove_embedding = glove_dict()

    # Initialize and fit Keras tokenizer to convert words to integers
    tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=VOCAB_SIZE)
    tokenizer.fit_on_texts(corpus)

    # Save the tokenizer as a pickle file so that the same tokenizer (word-integer)
    # mapping can be used during testing time
    with open('Tokenizer/tokenizer.pickle', "wb") as file:
        pickle.dump(tokenizer, file)

    # Get an word-integer dictionary and use that to create an weight matrix
    # i-th column of weight matrix will have the vector of word with integer value i in dictionary
    word_index = tokenizer.word_index
    embed_matrix = np.zeros((len(word_index) + 1, 100))

    for word, ind in word_index.items():
        # Get the embedding vector from GloVe dictionary, if available
        # Words not in the Glove would have the embedding matrix vector as random values uniformly generated between -0.05 and 0.05
        embedding_vector = glove_embedding.get(word)

        if embedding_vector is not None:
            embed_matrix[ind] = embedding_vector
        else:
            embed_matrix[ind] = np.array([np.random.uniform(-0.05, 0.05) for _ in range(100)])

    return embed_matrix, tokenizer

# %%
with open('train_data.pickle', "rb") as file:
        data = pickle.load(file)

# %%
MAX_SEQ_LEN = 500
VOCAB_SIZE = 200000

# %%
data, corpus = convert_data(data)
embed_matrix, tokenizer = embedding_matrix(corpus, VOCAB_SIZE)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
data = process(data)

# %%
embed_matrix.shape
# Out:
# (110449, 100)

# %%
lam = tf.keras.regularizers.L2(l2=0.01)
embedding = tf.keras.layers.Embedding(input_dim=embed_matrix.shape[0], output_dim=100, weights=[embed_matrix], input_length=MAX_SEQ_LEN, trainable=False)
translation = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(100, activation='relu', kernel_regularizer=lam))
lstm = tf.keras.layers.LSTM(100, kernel_regularizer=lam)

# %%
input_layer = tf.keras.layers.Input(shape=(MAX_SEQ_LEN,), dtype='int32')
embed_layer = embedding(input_layer)
translate_layer = translation(embed_layer)
lstm_layer = lstm(translate_layer)
dropout_layer = tf.keras.layers.Dropout(0.1)(lstm_layer)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(dropout_layer)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 500)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 500, 100)          11044900
# _________________________________________________________________
# time_distributed (TimeDistri (None, 500, 100)          10100
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               80400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 11,135,501
# Trainable params: 90,601
# Non-trainable params: 11,044,900
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.00001)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)

_, tmpfn = tempfile.mkstemp()
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)

callbacks = [model_checkpoint, learning_rate_reduction, early_stopping]

# %%
X_train = data[0]
y_train = data[1]

# %%
history = model.fit(x=X_train, y=y_train, epochs=50, batch_size=128, validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1/50
# 129/129 [==============================] - 18s 102ms/step - loss: 2.1697 - accuracy: 0.6605 - val_loss: 1.0397 - val_accuracy: 0.6865
# Epoch 2/50
# 129/129 [==============================] - 12s 90ms/step - loss: 0.9004 - accuracy: 0.7468 - val_loss: 0.7220 - val_accuracy: 0.8081
# Epoch 3/50
# 129/129 [==============================] - 12s 90ms/step - loss: 0.6774 - accuracy: 0.8113 - val_loss: 0.8840 - val_accuracy: 0.5896
# Epoch 4/50
# 129/129 [==============================] - 12s 90ms/step - loss: 0.7949 - accuracy: 0.6799 - val_loss: 0.5846 - val_accuracy: 0.8227
# Epoch 5/50
# 129/129 [==============================] - 12s 91ms/step - loss: 0.5825 - accuracy: 0.8128 - val_loss: 0.5908 - val_accuracy: 0.8074
# Epoch 6/50
# 129/129 [==============================] - 11s 88ms/step - loss: 0.5063 - accuracy: 0.8522 - val_loss: 0.4754 - val_accuracy: 0.8588
# Epoch 7/50
# 129/129 [==============================] - 11s 84ms/step - loss: 0.4438 - accuracy: 0.8688 - val_loss: 0.4536 - val_accuracy: 0.8471
# Epoch 8/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.5318 - accuracy: 0.8213 - val_loss: 0.4546 - val_accuracy: 0.8634
# Epoch 9/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.5536 - accuracy: 0.8109 - val_loss: 0.4594 - val_accuracy: 0.8639
# Epoch 10/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.4344 - accuracy: 0.8723 - val_loss: 0.4047 - val_accuracy: 0.8813
# Epoch 11/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3848 - accuracy: 0.8863 - val_loss: 0.3741 - val_accuracy: 0.8920
# Epoch 12/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3547 - accuracy: 0.8937 - val_loss: 0.3596 - val_accuracy: 0.8871
# Epoch 13/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3446 - accuracy: 0.8966 - val_loss: 0.3305 - val_accuracy: 0.8983
# Epoch 14/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3263 - accuracy: 0.8998 - val_loss: 0.3236 - val_accuracy: 0.9012
# Epoch 15/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.3089 - accuracy: 0.9061 - val_loss: 0.3096 - val_accuracy: 0.9065
# Epoch 16/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.3151 - accuracy: 0.9011 - val_loss: 0.3075 - val_accuracy: 0.9079
# Epoch 17/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3055 - accuracy: 0.9038 - val_loss: 0.2951 - val_accuracy: 0.9079
# Epoch 18/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2954 - accuracy: 0.9134 - val_loss: 0.3276 - val_accuracy: 0.8958
# Epoch 19/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.3004 - accuracy: 0.9080 - val_loss: 0.3096 - val_accuracy: 0.8978
# Epoch 20/50
# 129/129 [==============================] - 11s 83ms/step - loss: 0.2921 - accuracy: 0.9122 - val_loss: 0.2859 - val_accuracy: 0.9152
# Epoch 21/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2896 - accuracy: 0.9100 - val_loss: 0.2792 - val_accuracy: 0.9140
# Epoch 22/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2784 - accuracy: 0.9152 - val_loss: 0.2786 - val_accuracy: 0.9150
# Epoch 23/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2914 - accuracy: 0.9127 - val_loss: 0.2913 - val_accuracy: 0.9116
# Epoch 24/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.2709 - accuracy: 0.9200 - val_loss: 0.3225 - val_accuracy: 0.8944
# Epoch 25/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2689 - accuracy: 0.9162 - val_loss: 0.2844 - val_accuracy: 0.9169
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2521 - accuracy: 0.9254 - val_loss: 0.2625 - val_accuracy: 0.9198
# Epoch 27/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.2430 - accuracy: 0.9319 - val_loss: 0.2797 - val_accuracy: 0.9162
# Epoch 28/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.4766 - accuracy: 0.7904 - val_loss: 0.4181 - val_accuracy: 0.8626
# Epoch 29/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.3059 - accuracy: 0.9072 - val_loss: 0.2986 - val_accuracy: 0.9089
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.2595 - accuracy: 0.9233 - val_loss: 0.2680 - val_accuracy: 0.9210
# Epoch 31/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2462 - accuracy: 0.9307 - val_loss: 0.2645 - val_accuracy: 0.9208
# Epoch 32/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2394 - accuracy: 0.9330 - val_loss: 0.2665 - val_accuracy: 0.9164
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 33/50
# 129/129 [==============================] - 10s 79ms/step - loss: 0.2219 - accuracy: 0.9389 - val_loss: 0.2660 - val_accuracy: 0.9145

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
with open('test_data.pickle', "rb") as file:
        test_data = pickle.load(file)

# %%
with open('Tokenizer/tokenizer.pickle', "rb") as file:
        tokenizer = pickle.load(file)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
test_data = process(test_data)

# %%
X_test = test_data[0]
y_test = np.array(test_data[1])

# %%
X_test.shape, y_test.shape
# Out:
# ((5193, 500), (5193,))

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}, Test Accuracy: {:.2f}%\n".format(loss, (accuracy*100)))
# Out:
# 163/163 [==============================] - 3s 16ms/step - loss: 1.5942 - accuracy: 0.6312
# Test Loss: 1.59, Test Accuracy: 63.12%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

# %%
plt.figure(figsize=(8, 6))
ticks = ['Reliable', 'Unreliable']
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g', xticklabels=ticks, yticklabels=ticks)
plt.xlabel("True labels")
plt.ylabel("Predicted labels")
# Out:
# Text(51.0, 0.5, 'Predicted labels')

# %%
plt.figure(figsize=(8, 6))
report = classification_report(y_test, y_pred, output_dict=True, target_names=ticks)
sns.heatmap(pd.DataFrame(report).iloc[:-1, :3].T, annot=True)
# Out:
# <AxesSubplot:>
