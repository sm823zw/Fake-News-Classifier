# %%
import pickle
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def convert_data(data):
    sentence = data[0]
    corpus = [' '.join(item) for item in sentence]
    label = data[1]
    empty_idx = []
    for i in range(len(corpus)):
        if corpus[i] == '':
            empty_idx.append(i)
    empty_idx.sort(reverse=True)
    for i in empty_idx:
        del corpus[i]
        del sentence[i]
        del label[i]
    label = np.array(label)
    data_convert = [sentence, label]
    return data_convert, corpus
    
def glove_dict():
    embedding_dict = {}

    # Open the GloVe embedding file
    glove_dir = 'Embedding/glove.6B.100d.txt'
    file = open(glove_dir, encoding="utf8")

    for line in file:
        # Spilt the word and its embedding vector
        line_list = line.split(' ')
        word = line_list[0]
        embeddings = np.asarray(line_list[1:], dtype='float32')

        # Store the word and its embedding vector in a dictionary
        embedding_dict[word] = embeddings

    file.close()

    # Store the dictionary as a pickle file to reduce thw overhead of loading
    with open(f'Embedding/glove_dict_6b_100d.pickle', "wb") as file:
        pickle.dump(embedding_dict, file)

    return embedding_dict

def embedding_matrix(corpus, VOCAB_SIZE):
    # Try to load GloVe embedding dictionary if it exists. If not, create one
    try:
        with open(f'Embedding/glove_dict_6b_100d.pickle', "rb") as file:
            glove_embedding = pickle.load(file)
    except:
        glove_embedding = glove_dict()

    # Initialize and fit Keras tokenizer to convert words to integers
    tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=VOCAB_SIZE)
    tokenizer.fit_on_texts(corpus)

    # Save the tokenizer as a pickle file so that the same tokenizer (word-integer)
    # mapping can be used during testing time
    with open('Tokenizer/tokenizer.pickle', "wb") as file:
        pickle.dump(tokenizer, file)

    # Get an word-integer dictionary and use that to create an weight matrix
    # i-th column of weight matrix will have the vector of word with integer value i in dictionary
    word_index = tokenizer.word_index
    embed_matrix = np.zeros((len(word_index) + 1, 100))

    for word, ind in word_index.items():
        # Get the embedding vector from GloVe dictionary, if available
        # Words not in the Glove would have the embedding matrix vector as random values uniformly generated between -0.05 and 0.05
        embedding_vector = glove_embedding.get(word)

        if embedding_vector is not None:
            embed_matrix[ind] = embedding_vector
        else:
            embed_matrix[ind] = np.array([np.random.uniform(-0.05, 0.05) for _ in range(100)])

    return embed_matrix, tokenizer

# %%
with open('text_data.pickle', "rb") as file:
        data = pickle.load(file)

# %%
len(data[0])
# Out:
# 20761

# %%
sen = data[0]
lab = data[1]

# %%
train_data = [sen[0:17000], lab[0:17000]]
test_data = [sen[17000:], lab[17000:]]

# %%
MAX_SEQ_LEN = 1000
VOCAB_SIZE = 100000

# %%
train_data, corpus = convert_data(train_data)
embed_matrix, tokenizer = embedding_matrix(corpus, VOCAB_SIZE)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
train_data = process(train_data)

# %%
embed_matrix.shape
# Out:
# (99128, 100)

# %%
lam = tf.keras.regularizers.L2(l2=0.005)
embedding = tf.keras.layers.Embedding(input_dim=embed_matrix.shape[0], output_dim=100, weights=[embed_matrix], input_length=MAX_SEQ_LEN, trainable=False)
translation = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(100, activation='relu', kernel_regularizer=lam))
lstm = tf.keras.layers.LSTM(100, kernel_regularizer=lam)

# %%
input_layer = tf.keras.layers.Input(shape=(MAX_SEQ_LEN,), dtype='int32')
embed_layer = embedding(input_layer)
translate_layer = translation(embed_layer)
lstm_layer = lstm(translate_layer)
dropout_layer = tf.keras.layers.Dropout(0.1)(lstm_layer)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(dropout_layer)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1000)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, 1000, 100)         9912800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1000, 100)         10100
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               80400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,003,401
# Trainable params: 90,601
# Non-trainable params: 9,912,800
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=6, verbose=1, factor=0.5, min_lr=0.00001)

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)

_, tmpfn = tempfile.mkstemp()
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)

callbacks = [model_checkpoint, learning_rate_reduction]

# %%
X_train = train_data[0]
y_train = train_data[1]

# %%
history = model.fit(x=X_train, y=y_train, epochs=100, batch_size=128, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/100
# 119/119 [==============================] - 22s 158ms/step - loss: 2.2261 - accuracy: 0.6447 - val_loss: 0.8755 - val_accuracy: 0.8006
# Epoch 2/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.7782 - accuracy: 0.8219 - val_loss: 0.5740 - val_accuracy: 0.8639
# Epoch 3/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.7960 - accuracy: 0.7308 - val_loss: 0.8409 - val_accuracy: 0.7012
# Epoch 4/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.7706 - accuracy: 0.7546 - val_loss: 0.7790 - val_accuracy: 0.7320
# Epoch 5/100
# 119/119 [==============================] - 18s 152ms/step - loss: 0.6890 - accuracy: 0.7910 - val_loss: 0.5938 - val_accuracy: 0.8290
# Epoch 6/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.5880 - accuracy: 0.8394 - val_loss: 0.6616 - val_accuracy: 0.7763
# Epoch 7/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.5670 - accuracy: 0.8388 - val_loss: 0.4896 - val_accuracy: 0.8651
# Epoch 8/100
# 119/119 [==============================] - 18s 154ms/step - loss: 0.4871 - accuracy: 0.8693 - val_loss: 0.5374 - val_accuracy: 0.8355
# Epoch 9/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.4749 - accuracy: 0.8683 - val_loss: 0.4429 - val_accuracy: 0.8864
# Epoch 10/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.4441 - accuracy: 0.8782 - val_loss: 0.4120 - val_accuracy: 0.8882
# Epoch 11/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.4220 - accuracy: 0.8840 - val_loss: 0.4017 - val_accuracy: 0.8911
# Epoch 12/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.3863 - accuracy: 0.8952 - val_loss: 0.4201 - val_accuracy: 0.8657
# Epoch 13/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.4149 - accuracy: 0.8757 - val_loss: 0.4706 - val_accuracy: 0.8651
# Epoch 14/100
# 119/119 [==============================] - 18s 147ms/step - loss: 0.4436 - accuracy: 0.8692 - val_loss: 0.4276 - val_accuracy: 0.8751
# Epoch 15/100
# 119/119 [==============================] - 19s 157ms/step - loss: 0.4124 - accuracy: 0.8860 - val_loss: 0.3600 - val_accuracy: 0.8953
# Epoch 16/100
# 119/119 [==============================] - 18s 151ms/step - loss: 0.3566 - accuracy: 0.8988 - val_loss: 0.3496 - val_accuracy: 0.9053
# Epoch 17/100
# 119/119 [==============================] - 18s 147ms/step - loss: 0.3452 - accuracy: 0.9033 - val_loss: 0.3226 - val_accuracy: 0.9077
# Epoch 18/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.3239 - accuracy: 0.9120 - val_loss: 0.3214 - val_accuracy: 0.9101
# Epoch 19/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.3195 - accuracy: 0.9101 - val_loss: 0.3497 - val_accuracy: 0.8882
# Epoch 20/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.3054 - accuracy: 0.9151 - val_loss: 0.3102 - val_accuracy: 0.9112
# Epoch 21/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.3186 - accuracy: 0.9015 - val_loss: 0.3442 - val_accuracy: 0.9041
# Epoch 22/100
# 119/119 [==============================] - 18s 152ms/step - loss: 0.3666 - accuracy: 0.8910 - val_loss: 0.3380 - val_accuracy: 0.8959
# Epoch 23/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.3075 - accuracy: 0.9150 - val_loss: 0.4809 - val_accuracy: 0.8314
# Epoch 24/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.4135 - accuracy: 0.8681 - val_loss: 0.3334 - val_accuracy: 0.8959
# Epoch 25/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.3130 - accuracy: 0.9108 - val_loss: 0.2976 - val_accuracy: 0.9107
# Epoch 26/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.3073 - accuracy: 0.9148 - val_loss: 0.3405 - val_accuracy: 0.8959
# Epoch 27/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.2753 - accuracy: 0.9249 - val_loss: 0.2880 - val_accuracy: 0.9207
# Epoch 28/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.2837 - accuracy: 0.9210 - val_loss: 0.4841 - val_accuracy: 0.8556
# Epoch 29/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.3100 - accuracy: 0.9101 - val_loss: 0.3064 - val_accuracy: 0.9101
# Epoch 30/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.2651 - accuracy: 0.9275 - val_loss: 0.3250 - val_accuracy: 0.9012
# Epoch 31/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.2804 - accuracy: 0.9195 - val_loss: 0.2776 - val_accuracy: 0.9142
# Epoch 32/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2781 - accuracy: 0.9161 - val_loss: 0.2885 - val_accuracy: 0.9130
# Epoch 33/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.2499 - accuracy: 0.9308 - val_loss: 0.2605 - val_accuracy: 0.9154
# Epoch 34/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.2631 - accuracy: 0.9228 - val_loss: 0.2586 - val_accuracy: 0.9160
# Epoch 35/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2279 - accuracy: 0.9368 - val_loss: 0.2632 - val_accuracy: 0.9231
# Epoch 36/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.2532 - accuracy: 0.9286 - val_loss: 0.2813 - val_accuracy: 0.9148
# Epoch 37/100
# 119/119 [==============================] - 18s 151ms/step - loss: 0.2287 - accuracy: 0.9405 - val_loss: 0.2582 - val_accuracy: 0.9219
# Epoch 38/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2361 - accuracy: 0.9322 - val_loss: 0.2653 - val_accuracy: 0.9189
# Epoch 39/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2552 - accuracy: 0.9234 - val_loss: 0.2762 - val_accuracy: 0.9024
# Epoch 40/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2261 - accuracy: 0.9359 - val_loss: 0.2787 - val_accuracy: 0.9018
# Epoch 41/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2304 - accuracy: 0.9363 - val_loss: 0.2752 - val_accuracy: 0.9059
# Epoch 42/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3754 - accuracy: 0.8671 - val_loss: 0.4549 - val_accuracy: 0.8615
# Epoch 43/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.5417 - accuracy: 0.7935 - val_loss: 0.6178 - val_accuracy: 0.7284
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 44/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.5794 - accuracy: 0.7898 - val_loss: 0.6917 - val_accuracy: 0.6710
# Epoch 45/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.8938 - accuracy: 0.5985 - val_loss: 0.6849 - val_accuracy: 0.6923
# Epoch 46/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.7380 - accuracy: 0.6831 - val_loss: 0.5723 - val_accuracy: 0.7929
# Epoch 47/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.5547 - accuracy: 0.8144 - val_loss: 0.4155 - val_accuracy: 0.8805
# Epoch 48/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.4762 - accuracy: 0.8555 - val_loss: 0.4098 - val_accuracy: 0.8811
# Epoch 49/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.4415 - accuracy: 0.8707 - val_loss: 0.4001 - val_accuracy: 0.8793
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 50/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.4233 - accuracy: 0.8751 - val_loss: 0.3718 - val_accuracy: 0.8828
# Epoch 51/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.3874 - accuracy: 0.8892 - val_loss: 0.3728 - val_accuracy: 0.8905
# Epoch 52/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3879 - accuracy: 0.8878 - val_loss: 0.3530 - val_accuracy: 0.8959
# Epoch 53/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3751 - accuracy: 0.8939 - val_loss: 0.3424 - val_accuracy: 0.8982
# Epoch 54/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.3695 - accuracy: 0.8921 - val_loss: 0.3670 - val_accuracy: 0.8899
# Epoch 55/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3682 - accuracy: 0.8951 - val_loss: 0.3864 - val_accuracy: 0.8852
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 56/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3672 - accuracy: 0.8944 - val_loss: 0.3348 - val_accuracy: 0.9018
# Epoch 57/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3327 - accuracy: 0.9080 - val_loss: 0.3253 - val_accuracy: 0.9059
# Epoch 58/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3301 - accuracy: 0.9092 - val_loss: 0.3462 - val_accuracy: 0.9006
# Epoch 59/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.3407 - accuracy: 0.9031 - val_loss: 0.3186 - val_accuracy: 0.9130
# Epoch 60/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3187 - accuracy: 0.9128 - val_loss: 0.3199 - val_accuracy: 0.9077
# Epoch 61/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.3189 - accuracy: 0.9122 - val_loss: 0.3161 - val_accuracy: 0.9101
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 62/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.3122 - accuracy: 0.9159 - val_loss: 0.3134 - val_accuracy: 0.9112
# Epoch 63/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.3186 - accuracy: 0.9136 - val_loss: 0.3141 - val_accuracy: 0.9124
# Epoch 64/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3129 - accuracy: 0.9183 - val_loss: 0.3118 - val_accuracy: 0.9130
# Epoch 65/100
# 119/119 [==============================] - 18s 150ms/step - loss: 0.3071 - accuracy: 0.9173 - val_loss: 0.3087 - val_accuracy: 0.9095
# Epoch 66/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.3094 - accuracy: 0.9164 - val_loss: 0.3105 - val_accuracy: 0.9112
# Epoch 67/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.3142 - accuracy: 0.9159 - val_loss: 0.3030 - val_accuracy: 0.9148
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 68/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2902 - accuracy: 0.9259 - val_loss: 0.3032 - val_accuracy: 0.9154
# Epoch 69/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2932 - accuracy: 0.9231 - val_loss: 0.2999 - val_accuracy: 0.9183
# Epoch 70/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2983 - accuracy: 0.9206 - val_loss: 0.2989 - val_accuracy: 0.9201
# Epoch 71/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2889 - accuracy: 0.9266 - val_loss: 0.2989 - val_accuracy: 0.9154
# Epoch 72/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2840 - accuracy: 0.9247 - val_loss: 0.2971 - val_accuracy: 0.9201
# Epoch 73/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2904 - accuracy: 0.9260 - val_loss: 0.3216 - val_accuracy: 0.9107
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 74/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2905 - accuracy: 0.9243 - val_loss: 0.2990 - val_accuracy: 0.9166
# Epoch 75/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2821 - accuracy: 0.9278 - val_loss: 0.2949 - val_accuracy: 0.9183
# Epoch 76/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2758 - accuracy: 0.9309 - val_loss: 0.2951 - val_accuracy: 0.9213
# Epoch 77/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2876 - accuracy: 0.9272 - val_loss: 0.2989 - val_accuracy: 0.9166
# Epoch 78/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2796 - accuracy: 0.9270 - val_loss: 0.2936 - val_accuracy: 0.9189
# Epoch 79/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2817 - accuracy: 0.9268 - val_loss: 0.2940 - val_accuracy: 0.9213
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 80/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2887 - accuracy: 0.9234 - val_loss: 0.2933 - val_accuracy: 0.9201
# Epoch 81/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2823 - accuracy: 0.9254 - val_loss: 0.3000 - val_accuracy: 0.9160
# Epoch 82/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2807 - accuracy: 0.9252 - val_loss: 0.2927 - val_accuracy: 0.9195
# Epoch 83/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2730 - accuracy: 0.9319 - val_loss: 0.2932 - val_accuracy: 0.9183
# Epoch 84/100
# 119/119 [==============================] - 18s 147ms/step - loss: 0.2790 - accuracy: 0.9278 - val_loss: 0.2951 - val_accuracy: 0.9178
# Epoch 85/100
# 119/119 [==============================] - 18s 152ms/step - loss: 0.2814 - accuracy: 0.9259 - val_loss: 0.2929 - val_accuracy: 0.9207
# Epoch 86/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2740 - accuracy: 0.9331 - val_loss: 0.2917 - val_accuracy: 0.9225
# Epoch 87/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2775 - accuracy: 0.9297 - val_loss: 0.2926 - val_accuracy: 0.9195
# Epoch 88/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2779 - accuracy: 0.9291 - val_loss: 0.2913 - val_accuracy: 0.9231
# Epoch 89/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2702 - accuracy: 0.9321 - val_loss: 0.3025 - val_accuracy: 0.9178
# Epoch 90/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2823 - accuracy: 0.9248 - val_loss: 0.2895 - val_accuracy: 0.9219
# Epoch 91/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2766 - accuracy: 0.9268 - val_loss: 0.2965 - val_accuracy: 0.9172
# Epoch 92/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2828 - accuracy: 0.9253 - val_loss: 0.2936 - val_accuracy: 0.9201
# Epoch 93/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2743 - accuracy: 0.9289 - val_loss: 0.2900 - val_accuracy: 0.9201
# Epoch 94/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2746 - accuracy: 0.9299 - val_loss: 0.2873 - val_accuracy: 0.9178
# Epoch 95/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2754 - accuracy: 0.9301 - val_loss: 0.2878 - val_accuracy: 0.9219
# Epoch 96/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2673 - accuracy: 0.9309 - val_loss: 0.2930 - val_accuracy: 0.9183
# Epoch 97/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2658 - accuracy: 0.9300 - val_loss: 0.2870 - val_accuracy: 0.9213
# Epoch 98/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2656 - accuracy: 0.9325 - val_loss: 0.2875 - val_accuracy: 0.9219
# Epoch 99/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2606 - accuracy: 0.9342 - val_loss: 0.2854 - val_accuracy: 0.9178
# Epoch 100/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2631 - accuracy: 0.9323 - val_loss: 0.2851 - val_accuracy: 0.9201

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
with open('Tokenizer/tokenizer.pickle', "rb") as file:
        tokenizer = pickle.load(file)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
test_data = process(test_data)

# %%
X_test = test_data[0]
y_test = np.array(test_data[1])

# %%
X_test.shape, y_test.shape
# Out:
# ((3761, 1000), (3761,))

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}, Test Accuracy: {:.2f}%\n".format(loss, (accuracy*100)))
# Out:
# 118/118 [==============================] - 3s 25ms/step - loss: 0.2843 - accuracy: 0.9229
# Test Loss: 0.28, Test Accuracy: 92.29%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

# %%
plt.figure(figsize=(8, 6))
ticks = ['Reliable', 'Unreliable']
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g', xticklabels=ticks, yticklabels=ticks, annot_kws={"size":20})
plt.ylabel("True labels")
plt.xlabel("Predicted labels")
# Out:
# Text(51.0, 0.5, 'Predicted labels')

# %%
plt.figure(figsize=(8, 6))
report = classification_report(y_test, y_pred, output_dict=True, target_names=ticks)
sns.heatmap(pd.DataFrame(report).iloc[:-1, :2].T, annot=True, annot_kws={"size":20})
# Out:
# <AxesSubplot:>

# %%
tf.keras.models.save_model(model, 'text_model.h5')
