# %%
import pickle
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def convert_data(data):
    sentence = data[0]
    corpus = [' '.join(item) for item in sentence]
    label = data[1]
    empty_idx = []
    for i in range(len(corpus)):
        if corpus[i] == '':
            empty_idx.append(i)
    empty_idx.sort(reverse=True)
    for i in empty_idx:
        del corpus[i]
        del sentence[i]
        del label[i]
    label = np.array(label)
    data_convert = [sentence, label]
    return data_convert, corpus
    
def glove_dict():
    embedding_dict = {}

    # Open the GloVe embedding file
    glove_dir = 'Embedding/glove.6B.100d.txt'
    file = open(glove_dir, encoding="utf8")

    for line in file:
        # Spilt the word and its embedding vector
        line_list = line.split(' ')
        word = line_list[0]
        embeddings = np.asarray(line_list[1:], dtype='float32')

        # Store the word and its embedding vector in a dictionary
        embedding_dict[word] = embeddings

    file.close()

    # Store the dictionary as a pickle file to reduce thw overhead of loading
    with open(f'Embedding/glove_dict_6b_100d.pickle', "wb") as file:
        pickle.dump(embedding_dict, file)

    return embedding_dict

def embedding_matrix(corpus, VOCAB_SIZE):
    # Try to load GloVe embedding dictionary if it exists. If not, create one
    try:
        with open(f'Embedding/glove_dict_6b_100d.pickle', "rb") as file:
            glove_embedding = pickle.load(file)
    except:
        glove_embedding = glove_dict()

    # Initialize and fit Keras tokenizer to convert words to integers
    tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=VOCAB_SIZE)
    tokenizer.fit_on_texts(corpus)

    # Save the tokenizer as a pickle file so that the same tokenizer (word-integer)
    # mapping can be used during testing time
    with open('Tokenizer/tokenizer.pickle', "wb") as file:
        pickle.dump(tokenizer, file)

    # Get an word-integer dictionary and use that to create an weight matrix
    # i-th column of weight matrix will have the vector of word with integer value i in dictionary
    word_index = tokenizer.word_index
    embed_matrix = np.zeros((len(word_index) + 1, 100))

    for word, ind in word_index.items():
        # Get the embedding vector from GloVe dictionary, if available
        # Words not in the Glove would have the embedding matrix vector as random values uniformly generated between -0.05 and 0.05
        embedding_vector = glove_embedding.get(word)

        if embedding_vector is not None:
            embed_matrix[ind] = embedding_vector
        else:
            embed_matrix[ind] = np.array([np.random.uniform(-0.05, 0.05) for _ in range(100)])

    return embed_matrix, tokenizer

# %%
with open('text_data.pickle', "rb") as file:
        data = pickle.load(file)

# %%
len(data[0])
# Out:
# 20761

# %%
sen = data[0]
lab = data[1]

# %%
train_data = [sen[0:17000], lab[0:17000]]
test_data = [sen[17000:], lab[17000:]]

# %%
MAX_SEQ_LEN = 1000
VOCAB_SIZE = 100000

# %%
train_data, corpus = convert_data(train_data)
embed_matrix, tokenizer = embedding_matrix(corpus, VOCAB_SIZE)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
train_data = process(train_data)

# %%
embed_matrix.shape
# Out:
# (99128, 100)

# %%
lam = tf.keras.regularizers.L2(l2=0.005)
embedding = tf.keras.layers.Embedding(input_dim=embed_matrix.shape[0], output_dim=100, weights=[embed_matrix], input_length=MAX_SEQ_LEN, trainable=False)
translation = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(100, activation='relu', kernel_regularizer=lam))
lstm = tf.keras.layers.LSTM(100, kernel_regularizer=lam)

# %%
input_layer = tf.keras.layers.Input(shape=(MAX_SEQ_LEN,), dtype='int32')
embed_layer = embedding(input_layer)
translate_layer = translation(embed_layer)
lstm_layer = lstm(translate_layer)
dropout_layer = tf.keras.layers.Dropout(0.1)(lstm_layer)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(dropout_layer)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1000)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, 1000, 100)         9912800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1000, 100)         10100
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               80400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,003,401
# Trainable params: 90,601
# Non-trainable params: 9,912,800
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=6, verbose=1, factor=0.5, min_lr=0.00001)

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)

_, tmpfn = tempfile.mkstemp()
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)

callbacks = [model_checkpoint, learning_rate_reduction]

# %%
X_train = train_data[0]
y_train = train_data[1]

# %%
history = model.fit(x=X_train, y=y_train, epochs=100, batch_size=128, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/100
# 119/119 [==============================] - 28s 178ms/step - loss: 1.4451 - accuracy: 0.6770 - val_loss: 0.7887 - val_accuracy: 0.8178
# Epoch 2/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.7289 - accuracy: 0.8282 - val_loss: 0.6017 - val_accuracy: 0.8515
# Epoch 3/100
# 119/119 [==============================] - 18s 152ms/step - loss: 0.7044 - accuracy: 0.7783 - val_loss: 0.5425 - val_accuracy: 0.8698
# Epoch 4/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.7169 - accuracy: 0.7624 - val_loss: 0.6396 - val_accuracy: 0.8130
# Epoch 5/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.6425 - accuracy: 0.8170 - val_loss: 0.5767 - val_accuracy: 0.8331
# Epoch 6/100
# 119/119 [==============================] - 18s 147ms/step - loss: 0.6248 - accuracy: 0.8048 - val_loss: 0.5359 - val_accuracy: 0.8562
# Epoch 7/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.5333 - accuracy: 0.8523 - val_loss: 0.4608 - val_accuracy: 0.8834
# Epoch 8/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.6389 - accuracy: 0.7819 - val_loss: 0.6437 - val_accuracy: 0.7970
# Epoch 9/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.6096 - accuracy: 0.8163 - val_loss: 0.7649 - val_accuracy: 0.6888
# Epoch 10/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.6949 - accuracy: 0.7344 - val_loss: 0.6033 - val_accuracy: 0.7905
# Epoch 11/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.5432 - accuracy: 0.8380 - val_loss: 0.4673 - val_accuracy: 0.8757
# Epoch 12/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.4631 - accuracy: 0.8778 - val_loss: 0.4135 - val_accuracy: 0.8923
# Epoch 13/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.4204 - accuracy: 0.8850 - val_loss: 0.3631 - val_accuracy: 0.9006
# Epoch 14/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.3800 - accuracy: 0.8950 - val_loss: 0.3413 - val_accuracy: 0.9112
# Epoch 15/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.3522 - accuracy: 0.9052 - val_loss: 0.3209 - val_accuracy: 0.9154
# Epoch 16/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.3282 - accuracy: 0.9150 - val_loss: 0.3194 - val_accuracy: 0.9166
# Epoch 17/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.3277 - accuracy: 0.9105 - val_loss: 0.3288 - val_accuracy: 0.9059
# Epoch 18/100
# 119/119 [==============================] - 18s 147ms/step - loss: 0.2975 - accuracy: 0.9220 - val_loss: 0.3295 - val_accuracy: 0.9160
# Epoch 19/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.3007 - accuracy: 0.9211 - val_loss: 0.3176 - val_accuracy: 0.9118
# Epoch 20/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2841 - accuracy: 0.9246 - val_loss: 0.2915 - val_accuracy: 0.9201
# Epoch 21/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2777 - accuracy: 0.9262 - val_loss: 0.2768 - val_accuracy: 0.9237
# Epoch 22/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2676 - accuracy: 0.9302 - val_loss: 0.3218 - val_accuracy: 0.9030
# Epoch 23/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2424 - accuracy: 0.9418 - val_loss: 0.2761 - val_accuracy: 0.9272
# Epoch 24/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2438 - accuracy: 0.9403 - val_loss: 0.2747 - val_accuracy: 0.9272
# Epoch 25/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2486 - accuracy: 0.9393 - val_loss: 0.2340 - val_accuracy: 0.9367
# Epoch 26/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2310 - accuracy: 0.9436 - val_loss: 0.2558 - val_accuracy: 0.9272
# Epoch 27/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2264 - accuracy: 0.9442 - val_loss: 0.2293 - val_accuracy: 0.9420
# Epoch 28/100
# 119/119 [==============================] - 17s 147ms/step - loss: 0.2085 - accuracy: 0.9535 - val_loss: 0.2310 - val_accuracy: 0.9379
# Epoch 29/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.1985 - accuracy: 0.9544 - val_loss: 0.2668 - val_accuracy: 0.9237
# Epoch 30/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2255 - accuracy: 0.9424 - val_loss: 0.2270 - val_accuracy: 0.9396
# Epoch 31/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1984 - accuracy: 0.9546 - val_loss: 0.3110 - val_accuracy: 0.9089
# Epoch 32/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.1999 - accuracy: 0.9541 - val_loss: 0.2316 - val_accuracy: 0.9385
# Epoch 33/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2118 - accuracy: 0.9462 - val_loss: 0.2665 - val_accuracy: 0.9225
# Epoch 34/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.2005 - accuracy: 0.9526 - val_loss: 0.2502 - val_accuracy: 0.9308
# Epoch 35/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2268 - accuracy: 0.9424 - val_loss: 0.2162 - val_accuracy: 0.9414
# Epoch 36/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.1836 - accuracy: 0.9596 - val_loss: 0.2463 - val_accuracy: 0.9278
# Epoch 37/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.1770 - accuracy: 0.9598 - val_loss: 0.2137 - val_accuracy: 0.9450
# Epoch 38/100
# 119/119 [==============================] - 18s 151ms/step - loss: 0.1859 - accuracy: 0.9583 - val_loss: 0.2411 - val_accuracy: 0.9254
# Epoch 39/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.1780 - accuracy: 0.9603 - val_loss: 0.2097 - val_accuracy: 0.9444
# Epoch 40/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.1739 - accuracy: 0.9582 - val_loss: 0.2849 - val_accuracy: 0.9083
# Epoch 41/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.1917 - accuracy: 0.9538 - val_loss: 0.2086 - val_accuracy: 0.9462
# Epoch 42/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1638 - accuracy: 0.9672 - val_loss: 0.2115 - val_accuracy: 0.9450
# Epoch 43/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.1572 - accuracy: 0.9679 - val_loss: 0.3100 - val_accuracy: 0.9095
# Epoch 44/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2624 - accuracy: 0.9321 - val_loss: 0.2952 - val_accuracy: 0.9178
# Epoch 45/100
# 119/119 [==============================] - 18s 149ms/step - loss: 0.2472 - accuracy: 0.9362 - val_loss: 0.2753 - val_accuracy: 0.9160
# Epoch 46/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2256 - accuracy: 0.9431 - val_loss: 0.2302 - val_accuracy: 0.9391
# Epoch 47/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2044 - accuracy: 0.9480 - val_loss: 0.2311 - val_accuracy: 0.9373
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 48/100
# 119/119 [==============================] - 18s 151ms/step - loss: 0.1899 - accuracy: 0.9541 - val_loss: 0.2286 - val_accuracy: 0.9391
# Epoch 49/100
# 119/119 [==============================] - 19s 163ms/step - loss: 0.1701 - accuracy: 0.9624 - val_loss: 0.2590 - val_accuracy: 0.9178
# Epoch 50/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.1853 - accuracy: 0.9517 - val_loss: 0.2223 - val_accuracy: 0.9420
# Epoch 51/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.1590 - accuracy: 0.9676 - val_loss: 0.2286 - val_accuracy: 0.9391
# Epoch 52/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.1538 - accuracy: 0.9675 - val_loss: 0.2282 - val_accuracy: 0.9373
# Epoch 53/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.1687 - accuracy: 0.9607 - val_loss: 0.2080 - val_accuracy: 0.9497
# Epoch 54/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1481 - accuracy: 0.9695 - val_loss: 0.2152 - val_accuracy: 0.9414
# Epoch 55/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1394 - accuracy: 0.9743 - val_loss: 0.2021 - val_accuracy: 0.9479
# Epoch 56/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.1603 - accuracy: 0.9621 - val_loss: 0.2013 - val_accuracy: 0.9479
# Epoch 57/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1310 - accuracy: 0.9782 - val_loss: 0.2120 - val_accuracy: 0.9438
# Epoch 58/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.1537 - accuracy: 0.9639 - val_loss: 0.2254 - val_accuracy: 0.9408
# Epoch 59/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1318 - accuracy: 0.9771 - val_loss: 0.2298 - val_accuracy: 0.9408
# Epoch 60/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1338 - accuracy: 0.9762 - val_loss: 0.2263 - val_accuracy: 0.9462
# Epoch 61/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.1200 - accuracy: 0.9810 - val_loss: 0.2095 - val_accuracy: 0.9450
# Epoch 62/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1197 - accuracy: 0.9824 - val_loss: 0.2050 - val_accuracy: 0.9479
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 63/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.1173 - accuracy: 0.9840 - val_loss: 0.2134 - val_accuracy: 0.9527
# Epoch 64/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.1021 - accuracy: 0.9887 - val_loss: 0.2172 - val_accuracy: 0.9509
# Epoch 65/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.1018 - accuracy: 0.9865 - val_loss: 0.2192 - val_accuracy: 0.9527
# Epoch 66/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.1011 - accuracy: 0.9858 - val_loss: 0.2136 - val_accuracy: 0.9462
# Epoch 67/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0940 - accuracy: 0.9888 - val_loss: 0.2114 - val_accuracy: 0.9473
# Epoch 68/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0898 - accuracy: 0.9903 - val_loss: 0.2084 - val_accuracy: 0.9509
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 69/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0821 - accuracy: 0.9942 - val_loss: 0.2239 - val_accuracy: 0.9497
# Epoch 70/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.0795 - accuracy: 0.9954 - val_loss: 0.2208 - val_accuracy: 0.9497
# Epoch 71/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0850 - accuracy: 0.9928 - val_loss: 0.2210 - val_accuracy: 0.9479
# Epoch 72/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0816 - accuracy: 0.9945 - val_loss: 0.2409 - val_accuracy: 0.9491
# Epoch 73/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0805 - accuracy: 0.9938 - val_loss: 0.2216 - val_accuracy: 0.9491
# Epoch 74/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0839 - accuracy: 0.9922 - val_loss: 0.2555 - val_accuracy: 0.9438
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 75/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0750 - accuracy: 0.9960 - val_loss: 0.2321 - val_accuracy: 0.9497
# Epoch 76/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.0752 - accuracy: 0.9961 - val_loss: 0.2501 - val_accuracy: 0.9473
# Epoch 77/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0718 - accuracy: 0.9980 - val_loss: 0.2521 - val_accuracy: 0.9509
# Epoch 78/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.0758 - accuracy: 0.9956 - val_loss: 0.2489 - val_accuracy: 0.9473
# Epoch 79/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0720 - accuracy: 0.9967 - val_loss: 0.2512 - val_accuracy: 0.9479
# Epoch 80/100
# 119/119 [==============================] - 17s 141ms/step - loss: 0.0704 - accuracy: 0.9981 - val_loss: 0.2677 - val_accuracy: 0.9462
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 81/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0661 - accuracy: 0.9980 - val_loss: 0.2583 - val_accuracy: 0.9491
# Epoch 82/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0663 - accuracy: 0.9987 - val_loss: 0.2573 - val_accuracy: 0.9462
# Epoch 83/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0659 - accuracy: 0.9983 - val_loss: 0.2553 - val_accuracy: 0.9456
# Epoch 84/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0665 - accuracy: 0.9988 - val_loss: 0.2596 - val_accuracy: 0.9479
# Epoch 85/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0639 - accuracy: 0.9990 - val_loss: 0.2662 - val_accuracy: 0.9485
# Epoch 86/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0673 - accuracy: 0.9975 - val_loss: 0.2656 - val_accuracy: 0.9485
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 87/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0638 - accuracy: 0.9988 - val_loss: 0.2647 - val_accuracy: 0.9491
# Epoch 88/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0635 - accuracy: 0.9989 - val_loss: 0.2719 - val_accuracy: 0.9479
# Epoch 89/100
# 119/119 [==============================] - 17s 142ms/step - loss: 0.0663 - accuracy: 0.9985 - val_loss: 0.2700 - val_accuracy: 0.9479
# Epoch 90/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0619 - accuracy: 0.9992 - val_loss: 0.2717 - val_accuracy: 0.9467
# Epoch 91/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0623 - accuracy: 0.9994 - val_loss: 0.2716 - val_accuracy: 0.9462
# Epoch 92/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0625 - accuracy: 0.9993 - val_loss: 0.2719 - val_accuracy: 0.9485
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 93/100
# 119/119 [==============================] - 18s 147ms/step - loss: 0.0620 - accuracy: 0.9994 - val_loss: 0.2731 - val_accuracy: 0.9485
# Epoch 94/100
# 119/119 [==============================] - 17s 144ms/step - loss: 0.0613 - accuracy: 0.9995 - val_loss: 0.2756 - val_accuracy: 0.9485
# Epoch 95/100
# 119/119 [==============================] - 17s 143ms/step - loss: 0.0616 - accuracy: 0.9991 - val_loss: 0.2777 - val_accuracy: 0.9485
# Epoch 96/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.0614 - accuracy: 0.9995 - val_loss: 0.2773 - val_accuracy: 0.9479
# Epoch 97/100
# 119/119 [==============================] - 17s 146ms/step - loss: 0.0611 - accuracy: 0.9994 - val_loss: 0.2741 - val_accuracy: 0.9473
# Epoch 98/100
# 119/119 [==============================] - 18s 148ms/step - loss: 0.0607 - accuracy: 0.9995 - val_loss: 0.2794 - val_accuracy: 0.9473
# Epoch 99/100
# 119/119 [==============================] - 19s 161ms/step - loss: 0.0613 - accuracy: 0.9991 - val_loss: 0.2805 - val_accuracy: 0.9473
# Epoch 100/100
# 119/119 [==============================] - 17s 145ms/step - loss: 0.0610 - accuracy: 0.9994 - val_loss: 0.2836 - val_accuracy: 0.9479

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
with open('Tokenizer/tokenizer.pickle', "rb") as file:
        tokenizer = pickle.load(file)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
test_data = process(test_data)

# %%
X_test = test_data[0]
y_test = np.array(test_data[1])

# %%
X_test.shape, y_test.shape
# Out:
# ((3761, 1000), (3761,))

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}, Test Accuracy: {:.2f}%\n".format(loss, (accuracy*100)))
# Out:
# 118/118 [==============================] - 3s 26ms/step - loss: 0.2885 - accuracy: 0.9450
# Test Loss: 0.29, Test Accuracy: 94.50%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

# %%
plt.figure(figsize=(8, 6))
ticks = ['Reliable', 'Unreliable']
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g', xticklabels=ticks, yticklabels=ticks, annot_kws={"size":20})
plt.ylabel("True labels")
plt.xlabel("Predicted labels")
# Out:
# Text(0.5, 33.0, 'Predicted labels')

# %%
plt.figure(figsize=(8, 6))
report = classification_report(y_test, y_pred, output_dict=True, target_names=ticks)
sns.heatmap(pd.DataFrame(report).iloc[:-1, :2].T, annot=True, annot_kws={"size":20})
# Out:
# <AxesSubplot:>

# %%
tf.keras.models.save_model(model, 'text_model.h5')
