# %%
import pickle
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def convert_data(data):
    sentence = data[0]
    corpus = [' '.join(item) for item in sentence]
    label = data[1]
    empty_idx = []
    for i in range(len(corpus)):
        if corpus[i] == '':
            empty_idx.append(i)
    empty_idx.sort(reverse=True)
    for i in empty_idx:
        del corpus[i]
        del sentence[i]
        del label[i]
    label = np.array(label)
    data_convert = [sentence, label]
    return data_convert, corpus
    
def glove_dict():
    embedding_dict = {}

    # Open the GloVe embedding file
    glove_dir = 'Embedding/glove.6B.100d.txt'
    file = open(glove_dir, encoding="utf8")

    for line in file:
        # Spilt the word and its embedding vector
        line_list = line.split(' ')
        word = line_list[0]
        embeddings = np.asarray(line_list[1:], dtype='float32')

        # Store the word and its embedding vector in a dictionary
        embedding_dict[word] = embeddings

    file.close()

    # Store the dictionary as a pickle file to reduce thw overhead of loading
    with open(f'Embedding/glove_dict_6b_100d.pickle', "wb") as file:
        pickle.dump(embedding_dict, file)

    return embedding_dict

def embedding_matrix(corpus, VOCAB_SIZE):
    # Try to load GloVe embedding dictionary if it exists. If not, create one
    try:
        with open(f'Embedding/glove_dict_6b_100d.pickle', "rb") as file:
            glove_embedding = pickle.load(file)
    except:
        glove_embedding = glove_dict()

    # Initialize and fit Keras tokenizer to convert words to integers
    tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=VOCAB_SIZE)
    tokenizer.fit_on_texts(corpus)

    # Save the tokenizer as a pickle file so that the same tokenizer (word-integer)
    # mapping can be used during testing time
    with open('Tokenizer/tokenizer.pickle', "wb") as file:
        pickle.dump(tokenizer, file)

    # Get an word-integer dictionary and use that to create an weight matrix
    # i-th column of weight matrix will have the vector of word with integer value i in dictionary
    word_index = tokenizer.word_index
    embed_matrix = np.zeros((len(word_index) + 1, 100))

    for word, ind in word_index.items():
        # Get the embedding vector from GloVe dictionary, if available
        # Words not in the Glove would have the embedding matrix vector as random values uniformly generated between -0.05 and 0.05
        embedding_vector = glove_embedding.get(word)

        if embedding_vector is not None:
            embed_matrix[ind] = embedding_vector
        else:
            embed_matrix[ind] = np.array([np.random.uniform(-0.05, 0.05) for _ in range(100)])

    return embed_matrix, tokenizer

# %%
with open('text_data.pickle', "rb") as file:
        data = pickle.load(file)

# %%
len(data[0])
# Out:
# 20761

# %%
sen = data[0]
lab = data[1]

# %%
train_data = [sen[0:17000], lab[0:17000]]
test_data = [sen[17000:], lab[17000:]]

# %%
MAX_SEQ_LEN = 1000
VOCAB_SIZE = 20000

# %%
train_data, corpus = convert_data(train_data)
embed_matrix, tokenizer = embedding_matrix(corpus, VOCAB_SIZE)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
train_data = process(train_data)

# %%
embed_matrix.shape
# Out:
# (99128, 100)

# %%
lam = tf.keras.regularizers.L2(l2=0.001)
embedding = tf.keras.layers.Embedding(input_dim=embed_matrix.shape[0], output_dim=100, weights=[embed_matrix], input_length=MAX_SEQ_LEN, trainable=False)
translation = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(100, activation='relu', kernel_regularizer=lam))
lstm = tf.keras.layers.LSTM(100, kernel_regularizer=lam)

# %%
input_layer = tf.keras.layers.Input(shape=(MAX_SEQ_LEN,), dtype='int32')
embed_layer = embedding(input_layer)
translate_layer = translation(embed_layer)
lstm_layer = lstm(translate_layer)
dropout_layer = tf.keras.layers.Dropout(0.1)(lstm_layer)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(dropout_layer)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1000)]            0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 1000, 100)         9912800
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1000, 100)         10100
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,003,401
# Trainable params: 90,601
# Non-trainable params: 9,912,800
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.00001)

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)

_, tmpfn = tempfile.mkstemp()
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)

callbacks = [model_checkpoint, learning_rate_reduction]

# %%
X_train = train_data[0]
y_train = train_data[1]

# %%
history = model.fit(x=X_train, y=y_train, epochs=50, batch_size=128, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 22s 167ms/step - loss: 0.7924 - accuracy: 0.6683 - val_loss: 0.5415 - val_accuracy: 0.8219
# Epoch 2/50
# 119/119 [==============================] - 19s 156ms/step - loss: 0.4907 - accuracy: 0.8522 - val_loss: 0.4018 - val_accuracy: 0.8763
# Epoch 3/50
# 119/119 [==============================] - 19s 156ms/step - loss: 0.4037 - accuracy: 0.8862 - val_loss: 0.4269 - val_accuracy: 0.8793
# Epoch 4/50
# 119/119 [==============================] - 18s 154ms/step - loss: 0.3794 - accuracy: 0.8902 - val_loss: 0.3398 - val_accuracy: 0.9041
# Epoch 5/50
# 119/119 [==============================] - 18s 155ms/step - loss: 0.3549 - accuracy: 0.8946 - val_loss: 0.3957 - val_accuracy: 0.8746
# Epoch 6/50
# 119/119 [==============================] - 19s 161ms/step - loss: 0.3604 - accuracy: 0.8868 - val_loss: 0.3205 - val_accuracy: 0.9107
# Epoch 7/50
# 119/119 [==============================] - 18s 154ms/step - loss: 0.5938 - accuracy: 0.7467 - val_loss: 0.6711 - val_accuracy: 0.6935
# Epoch 8/50
# 119/119 [==============================] - 18s 152ms/step - loss: 0.6087 - accuracy: 0.7453 - val_loss: 0.5418 - val_accuracy: 0.7911
# Epoch 9/50
# 119/119 [==============================] - 19s 158ms/step - loss: 0.5586 - accuracy: 0.7916 - val_loss: 0.3866 - val_accuracy: 0.8888
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/50
# 119/119 [==============================] - 18s 156ms/step - loss: 0.3860 - accuracy: 0.8868 - val_loss: 0.3911 - val_accuracy: 0.8799
# Epoch 11/50
# 119/119 [==============================] - 19s 163ms/step - loss: 0.3674 - accuracy: 0.8964 - val_loss: 0.3277 - val_accuracy: 0.9024
# Epoch 12/50
# 119/119 [==============================] - 18s 155ms/step - loss: 0.5371 - accuracy: 0.7882 - val_loss: 0.4766 - val_accuracy: 0.8166
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/50
# 119/119 [==============================] - 18s 149ms/step - loss: 0.4363 - accuracy: 0.8554 - val_loss: 0.3705 - val_accuracy: 0.8994
# Epoch 14/50
# 119/119 [==============================] - 17s 143ms/step - loss: 0.4084 - accuracy: 0.8706 - val_loss: 0.3442 - val_accuracy: 0.8982
# Epoch 15/50
# 119/119 [==============================] - 18s 149ms/step - loss: 0.3602 - accuracy: 0.8947 - val_loss: 0.3323 - val_accuracy: 0.9071
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2602 - accuracy: 0.9332 - val_loss: 0.2590 - val_accuracy: 0.9314
# Epoch 38/50
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2552 - accuracy: 0.9359 - val_loss: 0.2614 - val_accuracy: 0.9302
# Epoch 39/50
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2597 - accuracy: 0.9365 - val_loss: 0.2597 - val_accuracy: 0.9308
# Epoch 40/50
# 119/119 [==============================] - 18s 148ms/step - loss: 0.2523 - accuracy: 0.9375 - val_loss: 0.2606 - val_accuracy: 0.9325
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 41/50
# 119/119 [==============================] - 18s 148ms/step - loss: 0.2459 - accuracy: 0.9371 - val_loss: 0.2554 - val_accuracy: 0.9320
# Epoch 42/50
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2535 - accuracy: 0.9359 - val_loss: 0.2565 - val_accuracy: 0.9320
# Epoch 43/50
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2470 - accuracy: 0.9380 - val_loss: 0.2520 - val_accuracy: 0.9343
# Epoch 44/50
# 119/119 [==============================] - 17s 146ms/step - loss: 0.2503 - accuracy: 0.9373 - val_loss: 0.2512 - val_accuracy: 0.9308
# Epoch 45/50
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2435 - accuracy: 0.9378 - val_loss: 0.2492 - val_accuracy: 0.9349
# Epoch 46/50
# 119/119 [==============================] - 17s 145ms/step - loss: 0.2560 - accuracy: 0.9324 - val_loss: 0.2508 - val_accuracy: 0.9343
# Epoch 47/50
# 119/119 [==============================] - 17s 144ms/step - loss: 0.2412 - accuracy: 0.9401 - val_loss: 0.2500 - val_accuracy: 0.9349
# Epoch 48/50
# 119/119 [==============================] - 17s 142ms/step - loss: 0.2400 - accuracy: 0.9437 - val_loss: 0.2527 - val_accuracy: 0.9349
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 49/50
# 119/119 [==============================] - 17s 142ms/step - loss: 0.2404 - accuracy: 0.9442 - val_loss: 0.2467 - val_accuracy: 0.9367
# Epoch 50/50
# 119/119 [==============================] - 17s 142ms/step - loss: 0.2380 - accuracy: 0.9421 - val_loss: 0.2505 - val_accuracy: 0.9361

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
with open('Tokenizer/tokenizer.pickle', "rb") as file:
        tokenizer = pickle.load(file)
sequence = lambda sentence: tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(sentence), maxlen=MAX_SEQ_LEN)
process = lambda item: (sequence(item[0]), item[1])
test_data = process(test_data)

# %%
X_test = test_data[0]
y_test = np.array(test_data[1])

# %%
X_test.shape, y_test.shape
# Out:
# ((3761, 1000), (3761,))

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}, Test Accuracy: {:.2f}%\n".format(loss, (accuracy*100)))
# Out:
# 118/118 [==============================] - 3s 26ms/step - loss: 0.2780 - accuracy: 0.9271
# Test Loss: 0.28, Test Accuracy: 92.71%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

# %%
plt.figure(figsize=(8, 6))
ticks = ['Reliable', 'Unreliable']
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g', xticklabels=ticks, yticklabels=ticks)
plt.xlabel("True labels")
plt.ylabel("Predicted labels")
# Out:
# Text(51.0, 0.5, 'Predicted labels')

# %%
plt.figure(figsize=(8, 6))
report = classification_report(y_test, y_pred, output_dict=True, target_names=ticks)
sns.heatmap(pd.DataFrame(report).iloc[:-1, :3].T, annot=True)
# Out:
# <AxesSubplot:>
